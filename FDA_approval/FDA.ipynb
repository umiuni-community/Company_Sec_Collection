# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Input parameters
start_year = 2015  # Adjust for start year
end_year = 2025    # Adjust for end year
start_month = 1    # Adjust for start month (1 = January)
end_month = 1     # Adjust for end month (12 = December)
company_name = "Pfizer"  # Enter the company name to search for

# Function to fetch data for a given month and year
def fetch_approvals(month, year):
    url = f"https://www.accessdata.fda.gov/scripts/cder/daf/index.cfm?event=reportsSearch.process&rptName=1&reportSelectMonth={month}&reportSelectYear={year}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://www.accessdata.fda.gov/",
        "Connection": "keep-alive",
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        table = soup.find("table")
        if table:
            rows = table.find_all("tr")
            approvals = []
            for row in rows[1:]:  # Skip the header row
                cols = row.find_all("td")
                if cols:
                    approvals.append({
                        "Approval Date": cols[0].text.strip(),
                        "Drug Name": cols[1].text.strip(),
                        "Submission": cols[2].text.strip(),
                        "Active Ingredients": cols[3].text.strip(),
                        "Sponsor": cols[4].text.strip(),
                    })
            return approvals
    return []

# Loop through all months and years in the specified range
all_approvals = []
for year in range(start_year, end_year + 1):  # Loop through years
    for month in range(start_month, end_month + 1):  # Loop through months
        print(f"Fetching data for {month}/{year}...")
        month_approvals = fetch_approvals(month, year)
        all_approvals.extend(month_approvals)

# Convert to a DataFrame
df = pd.DataFrame(all_approvals)

# Filter for the specified company
filtered_approvals = df[df["Sponsor"].str.contains(company_name, case=False, na=False)]

# Display the results
if not filtered_approvals.empty:
    print(f"Approvals for {company_name}:")
    print(filtered_approvals)
else:
    print(f"No approvals found for {company_name} in the specified time range.")

# Save all approvals to a CSV
#df.to_csv(f"fda_approvals_{start_year}_to_{end_year}.csv", index=False)
#print(f"All approvals saved to fda_approvals_{company_name}_{start_year}_to_{end_year}.csv")

# Save company-specific approvals to a separate CSV (if found)
if not filtered_approvals.empty:
    filtered_approvals.to_csv(f"{company_name}_approvals_{start_year}_to_{end_year}.csv", index=False)
    print(f"{company_name} data saved to {company_name}_approvals_{start_year}_to_{end_year}.csv")
# Out:
# Fetching data for 1/2020...
# Fetching data for 2/2020...
# Fetching data for 3/2020...
# Fetching data for 4/2020...
# Fetching data for 5/2020...
# Fetching data for 6/2020...
# Fetching data for 7/2020...
# Fetching data for 8/2020...
# Fetching data for 9/2020...
# Fetching data for 10/2020...
# Fetching data for 11/2020...
# Fetching data for 12/2020...
# Fetching data for 1/2021...
# Fetching data for 2/2021...
# Fetching data for 3/2021...
# Fetching data for 4/2021...
# Fetching data for 5/2021...
# Fetching data for 6/2021...
# Fetching data for 7/2021...
# Fetching data for 8/2021...
# Fetching data for 9/2021...
# Fetching data for 10/2021...
# Fetching data for 11/2021...
# Fetching data for 12/2021...
# Fetching data for 1/2022...
# Fetching data for 2/2022...
# Fetching data for 3/2022...
# Fetching data for 4/2022...
# Fetching data for 5/2022...
# Fetching data for 6/2022...
# Fetching data for 7/2022...
# Fetching data for 8/2022...
# Fetching data for 9/2022...
# Fetching data for 10/2022...
# Fetching data for 11/2022...
# Fetching data for 12/2022...
# Fetching data for 1/2023...
# Fetching data for 2/2023...
# Fetching data for 3/2023...
# Fetching data for 4/2023...
# Fetching data for 5/2023...
# Fetching data for 6/2023...
# Fetching data for 7/2023...
# Fetching data for 8/2023...
# Fetching data for 9/2023...
# Fetching data for 10/2023...
# Fetching data for 11/2023...
# Fetching data for 12/2023...
# Fetching data for 1/2024...
# Fetching data for 2/2024...
# Fetching data for 3/2024...
# Fetching data for 4/2024...
# Fetching data for 5/2024...
# Fetching data for 6/2024...
# Fetching data for 7/2024...
# Fetching data for 8/2024...
# Fetching data for 9/2024...
# Fetching data for 10/2024...
# Fetching data for 11/2024...
# Fetching data for 12/2024...
# Fetching data for 1/2025...
# Fetching data for 2/2025...
# Fetching data for 3/2025...
# Fetching data for 4/2025...
# Fetching data for 5/2025...
# Fetching data for 6/2025...
# Fetching data for 7/2025...
# Fetching data for 8/2025...
# Fetching data for 9/2025...
# Fetching data for 10/2025...
# Fetching data for 11/2025...
# Fetching data for 12/2025...
# Approvals for Pfizer:
#       Approval Date                           Drug Name Submission  \
# 190      01/16/2020                  IXIFIBLA   #761072    SUPPL-6
# 303      01/24/2020              TRAZIMERABLA   #761081    SUPPL-2
# 386      01/30/2020              CAMPTOSARNDA   #020571   SUPPL-51
# 910      02/27/2020             NURTEC ODTNDA   #212728     ORIG-1
# 1002     03/04/2020      CLEOCIN PHOSPHATENDA   #050441   SUPPL-83
# ...             ...                                 ...        ...
# 26950    12/16/2024  DEPO-SUBQ PROVERA 104NDA   #021583   SUPPL-43
# 26972    12/17/2024                CEFOBIDNDA   #050551   SUPPL-47
# 27128    12/20/2024                IBRANCENDA   #207103   SUPPL-22
# 27140    12/20/2024                IBRANCENDA   #212436   SUPPL-10
# 27393    01/17/2025                ELELYSOBLA   #022458   SUPPL-33
#
#                 Active Ingredients     Sponsor
# 190                INFLIXIMAB-QBTX  PFIZER INC
# 303               TRASTUZUMAB-QYYP  PFIZER INC
# 386       IRINOTECAN HYDROCHLORIDE  PFIZER INC
# 910             RIMEGEPANT SULFATE      PFIZER
# 1002         CLINDAMYCIN PHOSPHATE      PFIZER
# ...                            ...         ...
# 26950  MEDROXYPROGESTERONE ACETATE      PFIZER
# 26972          CEFOPERAZONE SODIUM      PFIZER
# 27128                  PALBOCICLIB      PFIZER
# 27140                  PALBOCICLIB      PFIZER
# 27393           TALIGLUCERASE ALFA      PFIZER
#
# [275 rows x 5 columns]
# Pfizer data saved to Pfizer_approvals_2020_to_2025.csv
